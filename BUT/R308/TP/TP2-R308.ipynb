# %% [markdown]
# ### Livrables attendus et compétences:
#
# #### Livrables
#
# - Ce Notebook avec vos codes et des preuves de son fonctionnement.
# - Une validation par l'enseignant au cours du TP.
# - Le travail est individuel sauf contre indication.
# - Le travail est rendu sur github education. L'URL sera communiquée par l'enseignant.
#
# #### Compétences qui vont être alimentées:
#
#
# - Utiliser un système informatiques et ses outils.
# - Lire, exécuter, corriger et modifier un programme.
# - S'intégrer dans un environnement propice au développement et au travail collaboratif.
# - Lier entre aux deux apprentissages critiques.
#
# #### Composantes essentielles
#
# - Il respecte les règles métiers.
# - En utilisant une approche rigoureuse pour les dysfonctionnements.
# - Il assure une veille technologique.

# %% [markdown]
# Dès que vous le pouvez utilisez les patterns montrés par l'enseignant dans le  cours "Python avancée" pour coder.

# %% [markdown]
# # Révisions de BUT1

# %% [markdown]
# ## Exercice 1:  Dictionnaire
#
# Durée estimée 10 mn 3,5 pts
#
# - Créez un dictionnaire via dict()
# - Ajoutez des valeurs à l'aide D[clef]=valeur (prendre par exemple les os (windows , linux, mac , vms , aix , solaris )comme clefs et vos appréciations perso comme valeurs rattachées à cette clef.
# - Retrouvez une valeur avec D.get(clef)
# - Listez les clefs/valeurs à l'aide de la fonction items() via une boucle for.
# - Listez les clefs via keys() et les valeurs via values()

# %% [markdown]
# ## Exercice 2 Liste
#
# Durée estimée 10 mn 3,5 points
#
# Créez une liste des jours de la semaine.
#
# - Copiez là :
# lCopie = [:]
# - Enlevez samedi et dimanche via la function pop
# - Les rajouter via append
# - Extraire les éléments jeudi,vendredi de la liste.( slicing )
# - Affichez  la liste  inversée via un slicing[::-1]
# - Faire un tri de la liste via sort
# - Listez un élément sur 2 de la liste avec un tri décroissant
# - Quelle est la différence entre l.reverse()
#     et l[::-1] ?
# - Faire un cast de la liste en string avec un séparateur « ; »
# Pour cela utiliser la syntaxe  ";".join(liste)

# %% [markdown]
# ## Exercice 3: "shallow copy"  et "deep copy":
#
# Durée estimée: 5 mn
#  L1 = [['un','deux','trois'],1,2,3]
#
#       Vérifiez via la commande "is" que L1 est égal à L2
#
#        Enlevez 'un' de L1.
# Qu'y a t il dans L2 ?
# Utilisez le module deepcopy  et refaites les mêmes tests.
#
# Que veux donc dire shallow et deepcopy ?

# %% [markdown]
# ## Exercice 4 Reformatage d'un fichier DHCP (source sous licence http://creativecommons.org/licenses/by-sa/3.0/)
#
#
# Il vous est proposé dans l'exercice suivant de "parser" un fichier de configuration permettant la distribution d'adresses IP à des postes de travail. Dans un premier temps vous n'utiliserez pas la programmation orientée objet puis dans un second temps vous re-créerez votre code ens utilisant des objets.
#
#
# Durée estimée 30 mn 6pts
#
# Comme le formatage du fichier dhcpd.conf est très libre par rapport aux sauts de lignes, on va reformater le fichier à notre façon. Pour cela, on va fusionner toutes les lignes dans un string, que l'on pourra ensuite parser.
#
# Il s'agit donc ici d'implémenter cet algorithme en Python:
#
#     de lire le fichier ligne par ligne (utiliser le package fileinput)
#     d'éliminer les lignes vides et les commentaires (vous pouvez utilisez utiliser re.sub(...))
#     de concaténer le tout dans un string,
#     d'extraire les portions host {…} de ce string, (utilisez re.findall(...))
#     de stocker chaque portion extraite dans une liste hosts.
#     de faire un dump de cette liste.
#
# Extrait du Dump:
# ['host coquil-gw1 { hardware ethernet 00:1d:09:0a:33:db; fixed-address coquil-gw1; }', 'host perso-ducrot { hardware ethernet 00:18:8B:D2:1C:4E; fixed-address perso-ducrot; }', 'host fpl { hardware ethernet 00:26:b9:5d:32:32;...

# %%
# Out:
# ['host coquil-gw1 { hardware ethernet 00:1d:09:0a:33:db; fixed-address coquil-gw1; }', 'host perso-ducrot { hardware ethernet 00:18:8B:D2:1C:4E; fixed-address perso-ducrot; }', 'host fpl { hardware ethernet 00:26:b9:5d:32:32; fixed-address fpl; }']

# %% [markdown]
# ## Exercice 4 Parseur DHCP
#
# Source sous licence http://creativecommons.org/licenses/by-sa/3.0/.
#
# Durée estimée: 1h15 7pts
#
# Nous allons écrire un script qui parcours un fichier dhcpd.conf, et construit une structure de données contenant pour chaque host une liste d'attributs choisis, associés à leur valeur. Ci-dessous un exemple de la structure de données que l'on pourrait construire :
#
# ```
# 'fpl'       => {
#                   'ip' => 'fpl',
#                   'mac' => '00:26:b9:5d:32:32'
#                },
# 'roundcube' => {
#                   'ip' => 'roundcube',
#                   'mac' => '00:16:36:09:2d:b9'
#                },
# 'visiteur2' => {
#                   'mac' => '00:60:B0:D5:3B:05'
#                }
# ```
# Finalité
#
# Lorsque vous développez des composants logiciels, il peut être intéressant de les diffuser, pour vous même ou plus largement.
# Vous allez réécrire le parseur DHCP sous forme objet.
# Puis vous allez créer un paquet contenant une bibliothéque et un exécutable.
#
#
# Nous allons créer 2 classes (il est impératif d'utiliser la POO) :
#
#     une classe DHCP::Host, modélisant une entrée host du fichier dhcpd.conf
#     une classe DHCP::Database, modélisant l'ensemble des informations parsées du fichier dhcpd.conf (c'est-à-dire l'ensemble des entrées host).
#
# Pour cela, nous souhaitons que :
#
#     DHCP::Host dispose d'un constructeur avec 2 paramètres : le nom du host, et un hash pour les attributs
#     DHCP::Database dispose d'une méthode addPattern qui ajoute un nouvel attribut à extraire,
#     DHCP::Database dispose d'une méthode load qui parse le fichier dont le nom est fourni en argument,
#     DHCP::Database dispose d'une méthode dump qui visualise le contenu de la database.
#
# Le programme donnera la sortie suivante:
#
# python main.py
# 2: [DHCP::Host(hostname="coquil-gw1",attributes={'ip': 'coquil-gw1', 'mac': '00:1d:09:0a:33:db'}),
# 3:  DHCP::Host(hostname="fpl",attributes={'ip': 'fpl', 'mac': '00:26:b9:5d:32:32'}),
# 4:  DHCP::Host(hostname="roundcube",attributes={'ip': 'roundcube', 'mac': '00:16:36:09:2d:b9'}),
# 5:  DHCP::Host(hostname="deux",attributes={'ip': 'deux', 'mac': '00:14:38:63:6E:F3'}),
# 6:  DHCP::Host(hostname="visiteur1",attributes={'mac': '00:00:aa:be:93:5d'}),
# 7:  DHCP::Host(hostname="visiteur2",attributes={'mac': '00:60:B0:D5:3B:05'})]

# %%
# Out:
# [DHCP::Host(hostname=coquil-gw1 attributes={'mac': '00:1d:09:0a:33:db', 'ip': 'coquil-gw1'},
#  DHCP::Host(hostname=perso-ducrot attributes={'mac': '00:18:8B:D2:1C:4E', 'ip': 'perso-ducrot'},
#  DHCP::Host(hostname=fpl attributes={'mac': '00:26:b9:5d:32:32', 'ip': 'fpl'},
#  DHCP::Host(hostname=roundcube attributes={'mac': '00:16:36:09:2d:b9', 'ip': 'roundcube'},
#  DHCP::Host(hostname=elitebook-ens attributes={'mac': '68:b5:99:e7:37:5b', 'ip': 'elitebook-ens'},
#  DHCP::Host(hostname=un attributes={'mac': '00:1a:4b:10:df:b0', 'ip': 'un'},
#  DHCP::Host(hostname=secretariat attributes={'mac': '00:14:38:d4:33:e0', 'ip': 'secretariat'},
#  DHCP::Host(hostname=deux attributes={'mac': '00:14:38:63:6E:F3', 'ip': 'deux'},
#  DHCP::Host(hostname=unb attributes={'mac': '00:60:B0:D5:3B:05', 'ip': 'unb'},
#  DHCP::Host(hostname=imp-bibli attributes={'mac': '00:00:aa:be:93:5d', 'ip': 'imp-bibli'},
#  DHCP::Host(hostname=scan-bibli attributes={'mac': '00:14:38:9a:a1:27', 'ip': 'scan-bibli'},
#  DHCP::Host(hostname=imp-secr2 attributes={'mac': '00:1f:29:31:6f:68', 'ip': 'imp-secr2'},
#  DHCP::Host(hostname=PC-dept attributes={'mac': '00:18:8b:54:59:7a', 'ip': 'PC-dept'},
#  DHCP::Host(hostname=PC-bibli attributes={'mac': '00:18:8b:54:59:3b', 'ip': 'PC-bibli'},
#  DHCP::Host(hostname=PC-rech attributes={'mac': '00:24:e8:45:a1:b6', 'ip': 'PC-rech'},
#  DHCP::Host(hostname=PC-bibli-next attributes={'mac': '00:13:72:b4:7f:ec', 'ip': 'PC-bibli-next'},
#  DHCP::Host(hostname=debian attributes={'mac': '00:02:b3:21:05:d8', 'ip': 'debian'},
#  DHCP::Host(hostname=debian2 attributes={'mac': '00:04:23:a6:c8:58', 'ip': 'debian2'},
#  DHCP::Host(hostname=testF15 attributes={'mac': '00:0e:0c:3e:06:58', 'ip': 'testF15'},
#  DHCP::Host(hostname=idrac-filer2ang attributes={'mac': 'B8:AC:6F:93:B2:7C', 'ip': 'idrac-filer2ang'},
#  DHCP::Host(hostname=ubuntultsp attributes={'mac': '00:16:36:2b:c7:9f', 'ip': 'ubuntultsp'},
#  DHCP::Host(hostname=sogo attributes={'mac': '54:52:00:1e:74:40', 'ip': 'sogo'},
#  DHCP::Host(hostname=f14 attributes={'mac': '00:0e:0c:66:08:67', 'ip': 'f14'},
#  DHCP::Host(hostname=HP-test attributes={'mac': '00:22:64:29:c9:70', 'ip': 'HP-test'},
#  DHCP::Host(hostname=windows-capes1 attributes={'mac': '00:1d:09:03:42:80', 'ip': 'windows-capes1'},
#  DHCP::Host(hostname=testeon attributes={'mac': '00:e0:c5:54:1c:3a', 'ip': 'testeon'},
#  DHCP::Host(hostname=TCtest attributes={'mac': '64:31:50:f3:48:a4', 'ip': 'TCtest'},
#  DHCP::Host(hostname=perso-tanlei attributes={'mac': '04:1e:64:fc:83:f4', 'ip': 'perso-tanlei'},
#  DHCP::Host(hostname=perso-schaub attributes={'mac': '00:21:70:b5:49:ab', 'ip': 'perso-schaub'},
#  DHCP::Host(hostname=perso-loustau attributes={'mac': '18:a9:05:84:bc:a3', 'ip': 'perso-loustau'},
#  DHCP::Host(hostname=perso-igor attributes={'mac': '00:1d:09:d7:5d:c4', 'ip': 'perso-igor'},
#  DHCP::Host(hostname=perso-bresto attributes={'mac': '00:40:d0:28:c9:28', 'ip': 'perso-bresto'},
#  DHCP::Host(hostname=perso-Granger attributes={'mac': '00:14:22:b8:bb:95', 'ip': 'perso-Granger'},
#  DHCP::Host(hostname=perso-Mangolte attributes={'mac': '10:9a:dd:5e:13:90', 'ip': 'perso-Mangolte'},
#  DHCP::Host(hostname=perso-piotr attributes={'mac': '00:23:8b:0b:9a:61', 'ip': 'perso-piotr'},
#  DHCP::Host(hostname=portable-tanlei attributes={'mac': '00:16:cb:cb:6e:14', 'ip': 'portable-tanlei'},
#  DHCP::Host(hostname=portable-loustau attributes={'mac': '00:13:77:9d:b3:e7', 'ip': 'portable-loustau'},
#  DHCP::Host(hostname=portable-luck attributes={'mac': '00:08:0D:8D:76:50', 'ip': 'portable-luck'},
#  DHCP::Host(hostname=perso-chaumont attributes={'mac': '00:1d:60:be:71:92', 'ip': 'perso-chaumont'},
#  DHCP::Host(hostname=mac-thomas attributes={'mac': '00:11:24:d6:37:8a', 'ip': 'mac-thomas'},
#  DHCP::Host(hostname=vista-thomas attributes={'mac': '00:11:24:d6:37:8b', 'ip': 'vista-thomas'},
#  DHCP::Host(hostname=perso-assi attributes={'mac': 'c8:0a:a9:17:fa:26', 'ip': 'perso-assi'},
#  DHCP::Host(hostname=perso-menichi attributes={'mac': '00:14:2a:3e:ed:67', 'ip': 'perso-menichi'},
#  DHCP::Host(hostname=perso-danielN attributes={'mac': '00:0a:e4:4b:7f:9e', 'ip': 'perso-danielN'},
#  DHCP::Host(hostname=perso-lionel attributes={'mac': '00:23:8b:67:51:33', 'ip': 'perso-lionel'},
#  DHCP::Host(hostname=perso-naie attributes={'mac': '00:1b:38:19:c9:bb', 'ip': 'perso-naie'},
#  DHCP::Host(hostname=perso-landreau attributes={'mac': '00:0f:b0:8b:d5:5b', 'ip': 'perso-landreau'},
#  DHCP::Host(hostname=perso-labatte attributes={'mac': '00:21:85:47:3d:07', 'ip': 'perso-labatte'},
#  DHCP::Host(hostname=perso-bresto2 attributes={'mac': '00:23:8b:36:0f:b3', 'ip': 'perso-bresto2'},
#  DHCP::Host(hostname=visio attributes={'mac': '00:d0:d6:0d:94:7c', 'ip': 'visio'},
#  DHCP::Host(hostname=placohost2 attributes={'mac': '00:11:25:c4:60:72', 'ip': 'placohost2'},
#  DHCP::Host(hostname=placohost3 attributes={'mac': '00:11:25:c4:65:34', 'ip': 'placohost3'},
#  DHCP::Host(hostname=placohost5 attributes={'mac': '00:15:17:9c:02:66', 'ip': 'placohost5'},
#  DHCP::Host(hostname=coquille2 attributes={'mac': '00:1e:c9:d3:8d:b3', 'ip': 'coquille2'},
#  DHCP::Host(hostname=coquille1 attributes={'mac': 'b8:ac:6f:84:a6:df', 'ip': 'coquille1'},
#  DHCP::Host(hostname=wims attributes={'mac': '00:17:A4:F5:17:31', 'ip': 'wims'},
#  DHCP::Host(hostname=ibm1 attributes={'mac': '00:11:25:c4:65:fa', 'ip': 'ibm1'},
#  DHCP::Host(hostname=filer2ang attributes={'mac': '54:52:00:7d:57:91', 'ip': 'filer2ang'},
#  DHCP::Host(hostname=HP-evain attributes={'mac': '00:1e:0b:7b:a9:92', 'ip': 'HP-evain'},
#  DHCP::Host(hostname=install attributes={'mac': '54:52:00:25:88:be', 'ip': 'install'},
#  DHCP::Host(hostname=tartuffe attributes={'mac': '00:22:19:69:E6:17', 'ip': 'tartuffe'},
#  DHCP::Host(hostname=sganarelle attributes={'mac': '00:26:b9:43:65:8a', 'ip': 'sganarelle'},
#  DHCP::Host(hostname=nb-jaclin attributes={'mac': '5c:26:0a:1a:2a:92', 'ip': 'nb-jaclin'},
#  DHCP::Host(hostname=mini-dell attributes={'mac': '78:2b:cb:82:d6:f9', 'ip': 'mini-dell'},
#  DHCP::Host(hostname=fatclient attributes={'mac': '78:2b:cb:82:05:32', 'ip': 'fatclient'},
#  DHCP::Host(hostname=testldap attributes={'mac': '00:1a:a0:2b:56:26', 'ip': 'testldap'},
#  DHCP::Host(hostname=nfssrv2 attributes={'mac': '00:25:90:55:3f:e0', 'ip': 'nfssrv2'},
#  DHCP::Host(hostname=eon-bibli attributes={'mac': '00:e0:c5:54:7b:f5', 'ip': 'eon-bibli'},
#  DHCP::Host(hostname=d620-3 attributes={'mac': '00:18:8b:c4:d8:f1', 'ip': 'd620-3'},
#  DHCP::Host(hostname=d620-2 attributes={'mac': '00:18:8b:c4:2e:1b', 'ip': 'd620-2'},
#  DHCP::Host(hostname=d620-1 attributes={'mac': '00:18:8b:c4:2c:a2', 'ip': 'd620-1'},
#  DHCP::Host(hostname=latitude2100-1 attributes={'mac': '00:26:b9:12:b1:de', 'ip': 'latitude2100-1'},
#  DHCP::Host(hostname=latitude2100-2 attributes={'mac': '00:26:b9:12:b2:b3', 'ip': 'latitude2100-2'},
#  DHCP::Host(hostname=latitude2100-3 attributes={'mac': '00:26:b9:12:b3:50', 'ip': 'latitude2100-3'},
#  DHCP::Host(hostname=d620-j attributes={'mac': '00:15:c5:57:3f:dc', 'ip': 'd620-j'},
#  DHCP::Host(hostname=coquille4 attributes={'mac': '00:1d:09:06:ad:2a', 'ip': 'coquille4'},
#  DHCP::Host(hostname=perso-irfan attributes={'mac': '68:b5:99:e6:b9:af', 'ip': 'perso-irfan'},
#  DHCP::Host(hostname=nb-bayle attributes={'mac': '64:31:50:10:fe:45', 'ip': 'nb-bayle'},
#  DHCP::Host(hostname=nb-reider attributes={'mac': '64:31:50:10:f2:9c', 'ip': 'nb-reider'},
#  DHCP::Host(hostname=nb-granger attributes={'mac': '64:31:50:10:f7:0a', 'ip': 'nb-granger'},
#  DHCP::Host(hostname=nfsfpl attributes={'mac': '78:2b:cb:12:f8:b1', 'ip': 'nfsfpl'},
#  DHCP::Host(hostname=calcfpl attributes={'mac': 'bc:30:5b:d3:e7:e4', 'ip': 'calcfpl'},
#  DHCP::Host(hostname=pticrem attributes={'mac': '00:25:64:e0:76:e3', 'ip': 'pticrem'},
#  DHCP::Host(hostname=HP-dubois attributes={'mac': '78:e7:d1:b4:a0:4a', 'ip': 'HP-dubois'},
#  DHCP::Host(hostname=HP-mahmood attributes={'mac': '00:22:64:29:cf:a4', 'ip': 'HP-mahmood'},
#  DHCP::Host(hostname=HP-assi attributes={'mac': '78:e7:d1:b4:a2:35', 'ip': 'HP-assi'},
#  DHCP::Host(hostname=HP-loeb attributes={'mac': '78:e7:d1:b4:9d:76', 'ip': 'HP-loeb'},
#  DHCP::Host(hostname=HP-ellanskaya attributes={'mac': 'd8:d3:85:9d:43:08', 'ip': 'HP-ellanskaya'},
#  DHCP::Host(hostname=HP-garbit attributes={'mac': '78:e7:d1:b5:a9:7c', 'ip': 'HP-garbit'},
#  DHCP::Host(hostname=HP-thomas attributes={'mac': '78:e7:d1:b5:a2:03', 'ip': 'HP-thomas'},
#  DHCP::Host(hostname=HP-vostrikova attributes={'mac': '78:e7:d1:b4:a0:38', 'ip': 'HP-vostrikova'},
#  DHCP::Host(hostname=HP-bulois attributes={'mac': '00:25:b3:d5:4a:71', 'ip': 'HP-bulois'},
#  DHCP::Host(hostname=HP-loday attributes={'mac': '00:22:64:29:cc:e5', 'ip': 'HP-loday'},
#  DHCP::Host(hostname=HP-lo attributes={'mac': 'f4:ce:46:fc:25:33', 'ip': 'HP-lo'},
#  DHCP::Host(hostname=HP-tanlei attributes={'mac': '78:e7:d1:b4:a0:0f', 'ip': 'HP-tanlei'},
#  DHCP::Host(hostname=HP-granger attributes={'mac': '78:e7:d1:b4:a0:18', 'ip': 'HP-granger'},
#  DHCP::Host(hostname=HP-ducrot attributes={'mac': '18:a9:05:35:9a:f8', 'ip': 'HP-ducrot'},
#  DHCP::Host(hostname=dell-I010f attributes={'mac': '00:13:72:D4:C6:B2', 'ip': 'dell-I010f'},
#  DHCP::Host(hostname=HP-mangolte attributes={'mac': '78:e7:d1:b6:a3:a9', 'ip': 'HP-mangolte'},
#  DHCP::Host(hostname=HP-wang attributes={'mac': 'f4:ce:46:fc:24:8a', 'ip': 'HP-wang'},
#  DHCP::Host(hostname=HP-chaumont attributes={'mac': 'f4:ce:46:fc:23:c9', 'ip': 'HP-chaumont'},
#  DHCP::Host(hostname=HP-denkowska attributes={'mac': '78:e7:d1:b5:a4:a6', 'ip': 'HP-denkowska'},
#  DHCP::Host(hostname=HP-darwich attributes={'mac': '78:e7:d1:b5:a6:37', 'ip': 'HP-darwich'},
#  DHCP::Host(hostname=HP-I107p attributes={'mac': '00:22:64:29:c0:0a', 'ip': 'HP-I107p'},
#  DHCP::Host(hostname=HP-I107m attributes={'mac': 'd8:d3:85:9d:42:87', 'ip': 'HP-I107m'},
#  DHCP::Host(hostname=HP-bayle attributes={'mac': '78:e7:d1:b6:e4:6b', 'ip': 'HP-bayle'},
#  DHCP::Host(hostname=dell-I010p attributes={'mac': '00:1d:09:03:25:83', 'ip': 'dell-I010p'},
#  DHCP::Host(hostname=dell-I011f attributes={'mac': '00:1e:c9:36:04:fe', 'ip': 'dell-I011f'},
#  DHCP::Host(hostname=dell-I009f attributes={'mac': '00:1d:09:0a:54:14', 'ip': 'dell-I009f'},
#  DHCP::Host(hostname=HP-belpaume attributes={'mac': '00:22:64:29:CC:33', 'ip': 'HP-belpaume'},
#  DHCP::Host(hostname=HP-bardet attributes={'mac': '00:23:7d:cb:ed:d3', 'ip': 'HP-bardet'},
#  DHCP::Host(hostname=HP-menichi attributes={'mac': '00:1e:0b:7a:c4:2b', 'ip': 'HP-menichi'},
#  DHCP::Host(hostname=HP-graczyk attributes={'mac': '00:1e:0b:7a:c8:6b', 'ip': 'HP-graczyk'},
#  DHCP::Host(hostname=HP-elamrani attributes={'mac': '78:e7:d1:b4:9c:94', 'ip': 'HP-elamrani'},
#  DHCP::Host(hostname=HP-landreau attributes={'mac': '78:e7:d1:b4:9f:88', 'ip': 'HP-landreau'},
#  DHCP::Host(hostname=HP-delabaere attributes={'mac': '78:e7:d1:b4:a0:41', 'ip': 'HP-delabaere'},
#  DHCP::Host(hostname=dell-I011p attributes={'mac': '00:12:3f:b3:b3:76', 'ip': 'dell-I011p'},
#  DHCP::Host(hostname=DELL-I116 attributes={'mac': '00:0f:1f:e3:63:13', 'ip': 'DELL-I116'},
#  DHCP::Host(hostname=HP-charbonnel attributes={'mac': '78:e7:d1:b4:9c:39', 'ip': 'HP-charbonnel'},
#  DHCP::Host(hostname=dell-I107f attributes={'mac': '00:18:8B:20:9F:01', 'ip': 'dell-I107f'},
#  DHCP::Host(hostname=HP-schaub attributes={'mac': '78:e7:d1:b4:a0:3d', 'ip': 'HP-schaub'},
#  DHCP::Host(hostname=HP-alexander attributes={'mac': '78:e7:d1:b5:a9:0b', 'ip': 'HP-alexander'},
#  DHCP::Host(hostname=HP-darniere attributes={'mac': '78:e7:d1:b6:a7:bd', 'ip': 'HP-darniere'},
#  DHCP::Host(hostname=HP-naie attributes={'mac': '78:e7:d1:b6:eb:5f', 'ip': 'HP-naie'},
#  DHCP::Host(hostname=HP-vienne attributes={'mac': '78:e7:d1:b4:a0:17', 'ip': 'HP-vienne'},
#  DHCP::Host(hostname=HP-cafasso attributes={'mac': '2c:27:d7:52:c4:90', 'ip': 'HP-cafasso'},
#  DHCP::Host(hostname=HP-monnier attributes={'mac': '78:e7:d1:b4:9d:1f', 'ip': 'HP-monnier'},
#  DHCP::Host(hostname=HP-loustau attributes={'mac': '00:1e:0b:7b:b8:00', 'ip': 'HP-loustau'},
#  DHCP::Host(hostname=HP-yafei attributes={'mac': 'd8:d3:85:9d:3a:15', 'ip': 'HP-yafei'},
#  DHCP::Host(hostname=HP-roubtsov attributes={'mac': '78:e7:d1:b6:e7:a4', 'ip': 'HP-roubtsov'},
#  DHCP::Host(hostname=HP-reider attributes={'mac': '78:e7:d1:b6:e4:df', 'ip': 'HP-reider'},
#  DHCP::Host(hostname=HP-boutat attributes={'mac': '78:e7:d1:b4:9a:37', 'ip': 'HP-boutat'},
#  DHCP::Host(hostname=HP-labatte attributes={'mac': '78:e7:d1:b6:ea:bc', 'ip': 'HP-labatte'},
#  DHCP::Host(hostname=dell-I116p attributes={'mac': '00:12:3F:B1:45:87', 'ip': 'dell-I116p'},
#  DHCP::Host(hostname=dell-lucas attributes={'mac': '00:1d:09:02:fd:ff', 'ip': 'dell-lucas'},
#  DHCP::Host(hostname=HP-maynadier attributes={'mac': '00:1e:0b:7b:b8:c6', 'ip': 'HP-maynadier'},
#  DHCP::Host(hostname=HP-brestovski attributes={'mac': '78:e7:d1:b4:a0:35', 'ip': 'HP-brestovski'},
#  DHCP::Host(hostname=dellmonitor attributes={'mac': '54:52:00:7d:57:12', 'ip': 'dellmonitor'},
#  DHCP::Host(hostname=dell-I116f attributes={'mac': '00:1d:09:02:f2:b3', 'ip': 'dell-I116f'},
#  DHCP::Host(hostname=guest-liu attributes={'mac': 'f0:de:f1:34:20:7c'},
#  DHCP::Host(hostname=guest-dongho attributes={'mac': '00:1f:16:df:00:f9'},
#  DHCP::Host(hostname=guest-moulahi attributes={'mac': '00:1d:72:f2:ba:a7'},
#  DHCP::Host(hostname=guest-ducrot attributes={'mac': '10:1f:74:e9:9c:5e'}]
